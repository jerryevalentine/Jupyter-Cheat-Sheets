# %%
import pandas as pd

# Replace 'your_file.csv' with the actual file path or URL
df = pd.read_csv('Resources/comic_books.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                         Title  \
# 0                                    10 dance
# 1                  100 Bullets : Brother Lono
# 2  100 Bullets : the deluxe edition book five
# 3                                 100 bullets
# 4                                   1000 cuts
#
#                                         Other titles  \
# 0                                          Ten dance
# 1                                       Brother Lono
# 2                                One hundred bullets
# 3  Counterfifth detective ; Decayed ; Dirty ; Fir...
# 4  Deathmatch. Volume two. A thousand cuts ; Thou...
#
#                             ISBN  \
# 0                  9781632367655
# 1                  9781401245061
# 2  9781401242718 ; 9781401261337
# 3                            NaN
# 4                  9781608863310
#
#                                            All names Series title  \
# 0               Inouesatoh, artist ; author [person]          NaN
# ...
